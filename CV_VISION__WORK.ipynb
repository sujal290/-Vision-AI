# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal290/-Vision-AI/blob/main/CV_VISION__WORK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# VISION AI IN 5 DAYS - FINAL PROJECT
# =========================
# Sujal Gupta

# !pip install -q kaggle tensorflow matplotlib seaborn scikit-learn

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras import datasets


from google.colab import files
files.upload()  # Upload kaggle.json here
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog -p /content --force
import zipfile
with zipfile.ZipFile('/content/cat-and-dog.zip','r') as zip_ref:
    zip_ref.extractall('/content/dogs-vs-cats')


# =================================
# DAY 01 - IMAGE RECOGNITION BASICS
# =================================
print("\n=== DAY 01: Loading MNIST Dataset ===")
(X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

plt.figure(figsize=(6, 6))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
plt.show()

# =================================
# DAY 02 - BASIC CNN MODEL (MNIST)
# =================================
print("\n=== DAY 02: Training CNN on MNIST ===")
model_mnist = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model_mnist.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model_mnist.fit(X_train, y_train, epochs=3, batch_size=32, validation_split=0.2)

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend()
plt.title('MNIST Accuracy')
plt.show()

print("Test Accuracy:", model_mnist.evaluate(X_test, y_test)[1])

# =================================
# DAY 03 - CIFAR-10 + AUGMENTATION
# =================================
print("\n=== DAY 03: Training CNN on CIFAR-10 with Augmentation ===")
(X_train_c10, y_train_c10), (X_test_c10, y_test_c10) = datasets.cifar10.load_data()
X_train_c10 = X_train_c10.astype('float32') / 255.0
X_test_c10 = X_test_c10.astype('float32') / 255.0

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train_c10)

model_cifar10 = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model_cifar10.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_cifar10.fit(datagen.flow(X_train_c10, y_train_c10, batch_size=32),
                  epochs=5, validation_data=(X_test_c10, y_test_c10))

y_pred_c10 = model_cifar10.predict(X_test_c10).argmax(axis=1)
cm = confusion_matrix(y_test_c10, y_pred_c10)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# =================================
# DAY 04 - TRANSFER LEARNING (CATS vs DOGS)
# =================================
print("\n=== DAY 04: Transfer Learning with MobileNetV2 ===")
# !kaggle datasets download -d tongpython/cat-and-dog -p /content --force
import zipfile
with zipfile.ZipFile('/content/cat-and-dog.zip','r') as zip_ref:
    zip_ref.extractall('/content/dogs-vs-cats')

datagen_cd = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_gen = datagen_cd.flow_from_directory(
    '/content/dogs-vs-cats',
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)
val_gen = datagen_cd.flow_from_directory(
    '/content/dogs-vs-cats',
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
base_model.trainable = False

model_cd = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model_cd.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_cd.fit(train_gen, epochs=3, validation_data=val_gen)

y_pred_proba = model_cd.predict(val_gen).ravel()
fpr, tpr, _ = roc_curve(val_gen.classes, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f'ROC AUC = {roc_auc:.2f}')
plt.plot([0,1], [0,1], 'k--')
plt.legend()
plt.show()

# =================================
# DAY 05 - FINAL PREDICTION + PORTFOLIO VISUAL
# =================================
print("\n=== DAY 05: Predicting on New Image ===")
from google.colab import files
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

from tensorflow.keras.preprocessing import image
img = image.load_img(img_path, target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)
prediction = model_cd.predict(img_array)
print("Predicted Class:", "Dog 🐶" if prediction[0][0] > 0.5 else "Cat 🐱")

# Portfolio bar chart
datasets_acc = ['MNIST', 'CIFAR-10', 'Cats vs Dogs']
acc_values = [
    model_mnist.evaluate(X_test, y_test, verbose=0)[1],
    model_cifar10.evaluate(X_test_c10, y_test_c10, verbose=0)[1],
    model_cd.evaluate(val_gen, verbose=0)[1]
]
plt.bar(datasets_acc, acc_values, color=['#36A2EB', '#FF6384', '#4BC0C0'])
plt.ylim(0, 1)
plt.title('Model Accuracies Across Datasets')
plt.show()
# Out:
#      <input type="file" id="files-983366e0-a0cd-4bc8-b111-4fbfae79c30d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-983366e0-a0cd-4bc8-b111-4fbfae79c30d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
